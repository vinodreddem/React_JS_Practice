# %%
f = open("practice1.txt",'w+')
f.write("""Classes provide a means of bundling data and functionality together. Creating a new class creates a new type of object, allowing new instances
of that type to be made. Each class instance can have attributes attached to it for maintaining its state. Class instances can also have methods (defined by its class) for modifying its state.
Compared with other programming languages, Python’s class mechanism adds classes with a minimum of new syntax and semantics. It is a mixture of the class mechanisms found in C++ and Modula-3.
Python classes provide all the standard features of Object Oriented Programming: the class inheritance mechanism allows multiple base classes, a derived class can override any methods of its base class or classes, 
and a method can call the method of a base class with the same name. Objects can contain arbitrary amounts and kinds of data.
As is true for modules, classes partake of the dynamic nature of Python: they are created at runtime, and can be modified further after creation.""")
        
f.close()

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ABILASH REDDY\\Desktop\\Complete-Python-3-Bootcamp-master\\12-Advanced Python Modules'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '00-Collections-Module.ipynb',
#  '01-Opening-and-Reading-Files-Folders.ipynb',
#  '02-Datetime-Module.ipynb',
#  '03-Math-and-Random-Module.ipynb',
#  '04-Python Debugger (pdb).ipynb',
#  '05-Overview-of-Regular-Expressions.ipynb',
#  '06-Timing your code - timeit.ipynb',
#  '07-Unzipping-and-Zipping-Files.ipynb',
#  '08-Advanced-Python-Module-Exercise',
#  'Example_Top_Level',
#  'practice.txt',
#  'practice1.txt',
#  'Untitled.ipynb']

# %%
os.listdir("C:\\Users")
# Out:
# ['ABILASH REDDY',
#  'All Users',
#  'Default',
#  'Default User',
#  'desktop.ini',
#  'Public']

# %%
import shutil

# %%
shutil.move("practice1.txt","C:\\Users\\ABILASH REDDY\\Desktop\\python")
# Out:
# 'C:\\Users\\ABILASH REDDY\\Desktop\\python\\practice1.txt'

# %%
os.listdir("C:\\Users\\ABILASH REDDY\\Desktop\\python")
# Out:
# ['.ipynb_checkpoints',
#  'fibo.py',
#  'practice1.txt',
#  'simpleone.py',
#  'sound',
#  'Untitled.ipynb',
#  '__pycache__']

# %%
import send2trash

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '00-Collections-Module.ipynb',
#  '01-Opening-and-Reading-Files-Folders.ipynb',
#  '02-Datetime-Module.ipynb',
#  '03-Math-and-Random-Module.ipynb',
#  '04-Python Debugger (pdb).ipynb',
#  '05-Overview-of-Regular-Expressions.ipynb',
#  '06-Timing your code - timeit.ipynb',
#  '07-Unzipping-and-Zipping-Files.ipynb',
#  '08-Advanced-Python-Module-Exercise',
#  'Example_Top_Level',
#  'practice.txt',
#  'Untitled.ipynb']

# %%
shutil.move("C:\\Users\\ABILASH REDDY\\Desktop\\python\practice1.txt",os.getcwd())
# Out:
# 'C:\\Users\\ABILASH REDDY\\Desktop\\Complete-Python-3-Bootcamp-master\\12-Advanced Python Modules\\practice1.txt'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '00-Collections-Module.ipynb',
#  '01-Opening-and-Reading-Files-Folders.ipynb',
#  '02-Datetime-Module.ipynb',
#  '03-Math-and-Random-Module.ipynb',
#  '04-Python Debugger (pdb).ipynb',
#  '05-Overview-of-Regular-Expressions.ipynb',
#  '06-Timing your code - timeit.ipynb',
#  '07-Unzipping-and-Zipping-Files.ipynb',
#  '08-Advanced-Python-Module-Exercise',
#  'Example_Top_Level',
#  'practice.txt',
#  'practice1.txt',
#  'Untitled.ipynb']

# %%
send2trash.send2trash("practice.txt")

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '00-Collections-Module.ipynb',
#  '01-Opening-and-Reading-Files-Folders.ipynb',
#  '02-Datetime-Module.ipynb',
#  '03-Math-and-Random-Module.ipynb',
#  '04-Python Debugger (pdb).ipynb',
#  '05-Overview-of-Regular-Expressions.ipynb',
#  '06-Timing your code - timeit.ipynb',
#  '07-Unzipping-and-Zipping-Files.ipynb',
#  '08-Advanced-Python-Module-Exercise',
#  'Example_Top_Level',
#  'practice1.txt',
#  'Untitled.ipynb']

# %%
filepath ="""C:\\Users\\ABILASH REDDY\\Desktop\\Complete-Python-3-Bootcamp-master\\12-Advanced Python Modules\\Example_Top_Level"""

# %%
for folder, sub_folders,files in os.walk(filepath):
    print(f"Currently looking at {folder}")
    print('\n')
    print("The sub folders are")
    for sub_fold in sub_folders:
        print(f"\t Subfolder: {sub_fold}")
        
    print('\n')
    print("the files are: ")
    for f in files:
        print(f"\t File: {f}")
    print("\n")
# Out:
# Currently looking at C:\Users\ABILASH REDDY\Desktop\Complete-Python-3-Bootcamp-master\12-Advanced Python Modules\Example_Top_Level
#
#
# The sub folders are
# 	 Subfolder: Mid-Example-One
#
#
# the files are:
# 	 File: Mid-Example.txt
#
#
# Currently looking at C:\Users\ABILASH REDDY\Desktop\Complete-Python-3-Bootcamp-master\12-Advanced Python Modules\Example_Top_Level\Mid-Example-One
#
#
# The sub folders are
# 	 Subfolder: Bottom-Level-One
# 	 Subfolder: Bottom-Level-Two
#
#
# the files are:
# 	 File: Mid-Level-Doc.txt
#
#
# Currently looking at C:\Users\ABILASH REDDY\Desktop\Complete-Python-3-Bootcamp-master\12-Advanced Python Modules\Example_Top_Level\Mid-Example-One\Bottom-Level-One
#
#
# The sub folders are
#
#
# the files are:
# 	 File: One_Text.txt
#
#
# Currently looking at C:\Users\ABILASH REDDY\Desktop\Complete-Python-3-Bootcamp-master\12-Advanced Python Modules\Example_Top_Level\Mid-Example-One\Bottom-Level-Two
#
#
# The sub folders are
#
#
# the files are:
# ...

# %%
os.getcwd()
# Out:
# 'C:\\Users\\ABILASH REDDY\\Desktop\\Complete-Python-3-Bootcamp-master\\12-Advanced Python Modules'

# %%
os.ctermid
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-ef95e4084d75> in <module>
# ----> 1 os.ctermid
#
# AttributeError: module 'os' has no attribute 'ctermid'

# %%
os.environ
# Out:
# environ{'ALLUSERSPROFILE': 'C:\\ProgramData',
#         'APPDATA': 'C:\\Users\\ABILASH REDDY\\AppData\\Roaming',
#         'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files',
#         'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files',
#         'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#         'COMPUTERNAME': 'LAPTOP-93QJEFOL',
#         'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe',
#         'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData',
#         'HADOOP_HOME': 'D:\\bhaskar\\hadoop',
#         'HOMEDRIVE': 'C:',
#         'HOMEPATH': '\\Users\\ABILASH REDDY',
#         'INTELLIJ IDEA COMMUNITY EDITION': 'C:\\Program Files\\JetBrains\\IntelliJ IDEA Community Edition 2021.2.1\\bin;',
#         'KAFKA_HOME': 'D:\\bhaskar\\kafka28',
#         'LOCALAPPDATA': 'C:\\Users\\ABILASH REDDY\\AppData\\Local',
#         'LOGONSERVER': '\\\\LAPTOP-93QJEFOL',
#         'M2_HOME': 'C:\\Program Files\\apache-maven-3.6.3',
# ...

# %%
os.fchdir()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-9343639ba709> in <module>
# ----> 1 os.fchdir()
#
# AttributeError: module 'os' has no attribute 'fchdir'

# %%
os.fchdir("C:\\Users\\ABILASH REDDY\\Desktop\\Complete-Python-3-Bootcamp-master\\12-Advanced Python Modules\\Example_Top_Level")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-0ee86a79b34b> in <module>
# ----> 1 os.fchdir("C:\\Users\\ABILASH REDDY\\Desktop\\Complete-Python-3-Bootcamp-master\\12-Advanced Python Modules\\Example_Top_Level")
#
# AttributeError: module 'os' has no attribute 'fchdir'

# %%
os.fspath("C:\\Users\\ABILASH REDDY\\Desktop\\Complete-Python-3-Bootcamp-master\\12-Advanced Python Modules\\Example_Top_Level")
# Out:
# 'C:\\Users\\ABILASH REDDY\\Desktop\\Complete-Python-3-Bootcamp-master\\12-Advanced Python Modules\\Example_Top_Level'

# %%
os.uname()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-dc3d352b2d7d> in <module>
# ----> 1 os.uname()
#
# AttributeError: module 'os' has no attribute 'uname'

# %%
import datetime

# %%
mytime = datetime.time(12,20,1,20)

# %%
print(mytime)
# Out:
# 12:20:01.000020

# %%
mytime.minute
# Out:
# 20

# %%
mytime.hour
# Out:
# 12

# %%
type(mytime)
# Out:
# datetime.time

# %%
today = datetime.date.today()

# %%
print(today)
# Out:
# 2021-10-04

# %%
today.year
# Out:
# 2021

# %%
today.day
# Out:
# 4

# %%
today.ctime()
# Out:
# 'Mon Oct  4 00:00:00 2021'

# %%
from datetime import datetime

# %%
mydatetime = datetime(2021,10,3,14,20,1)

# %%
print(mydatetime)
# Out:
# 2021-10-03 14:20:01

# %%
from datetime import date

# %%
date1 = date(2021,11,3)
date2 = date(2020,11,3)

# %%
date1 - date2
# Out:
# datetime.timedelta(days=365)

# %%
import math,io

# %%
help(io)
# Out:
# Help on module io:
#
# NAME
#     io
#
# MODULE REFERENCE
#     https://docs.python.org/3.8/library/io
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     The io module provides the Python interfaces to stream handling. The
#     builtin open function is defined in this module.
#
#     At the top of the I/O hierarchy is the abstract base class IOBase. It
#     defines the basic interface to a stream. Note, however, that there is no
#     separation between reading and writing to streams; implementations are
#     allowed to raise an OSError if they do not support a given operation.
#
#     Extending IOBase is RawIOBase which deals simply with the reading and
# ...

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.inf
# Out:
# inf

# %%
math.nan
# Out:
# nan

# %%
math.log(math.e)
# Out:
# 1.0

# %%
math.log(math.e,2)
# Out:
# 1.4426950408889634

# %%
math.log(math.e,10)
# Out:
# 0.43429448190325176

# %%
from math import pi

# %%
math.degrees(pi/2)
# Out:
# 90.0

# %%
import random

# %%
random.randint(1,10)
# Out:
# 6

# %%
random.seed(10001)
random.randint(1,100)
# Out:
# 46

# %%
random.randint(1,100)
# Out:
# 9

# %%
random.seed(101)
print(random.randint(1,100))
print(random.randint(1,100))
print(random.randint(1,100))
print(random.randint(1,100))
print(random.randint(1,100))
print(random.randint(1,100))
# Out:
# 75
# 25
# 70
# 46
# 60
# 7

# %%
mylist = list(range(1,21))

# %%
random.choice(mylist)
# Out:
# 9

# %%
# Sample with replacement

# %%
random.choices(mylist, k =10)
# Out:
# [4, 2, 16, 8, 10, 7, 13, 9, 5, 9]

# %%
# Sample without replacement
random.sample(mylist, k =10)
# Out:
# [10, 7, 4, 11, 9, 19, 13, 15, 18, 14]

# %%
random.uniform(0,5)
# Out:
# 2.0921778308793377

# %%
random.gauss(mu=0,sigma=1)
# Out:
# -0.2478730781589356

# %%
x = [1,2,3]
y = 2
z= 3

# %%
import  pdb

# %%
x = [1,2,3]
y = 2
z= 3 

result1 = y + z

pdb.set_trace()
result2 = y + x
# Out:
# --Return--
# None
# > <ipython-input-244-ed490515fe10>(7)<module>()
#       4
#       5 result1 = y + z
#       6
# ----> 7 pdb.set_trace()
#       8 result2 = y + x
#
# ipdb> x
# [1, 2, 3]
# ipdb> y
# 2
# ipdb> result
# 5
# ipdb> y
# 2
# ipdb> x
# [1, 2, 3]
# ipdb> x.append(y
# *** SyntaxError: unexpected EOF while parsing
# ipdb> x.append(y)
# ipdb> x
# [1, 2, 3, 2]
# ipdb> q
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-244-ed490515fe10> in <module>
#       5 result1 = y + z
#       6
# ----> 7 pdb.set_trace()
#       8 result2 = y + x
#
# C:\ProgramData\Anaconda3\lib\bdb.py in trace_dispatch(self, frame, event, arg)
#      90             return self.dispatch_call(frame, arg)
#      91         if event == 'return':
# ---> 92             return self.dispatch_return(frame, arg)
#      93         if event == 'exception':
# ...

# %%
for element in [1,2,3,4,5,False]:
    if not element:
        return False
    return True
# Out:
#   File "<ipython-input-250-b1aee8aeef20>", line 3
#     return False
#     ^
# SyntaxError: 'return' outside function

# %%
'dog' in 'my dog is great'
# Out:
# True

# %%
import re

# %%
text ='the agent phone number is (555)-555-5555. call soon'

# %%
'phone' in text
# Out:
# True

# %%
pattern = 'phone'

# %%
re.search(pattern, text)
# Out:
# <re.Match object; span=(10, 15), match='phone'>

# %%
re.search('Not in text', text)

# %%
match = re.search(pattern, text)

# %%
match.start()
# Out:
# 10

# %% [markdown]
# match.end()

# %%
match.end()
# Out:
# 15

# %%
text = 'my phone once and my phone twise'

# %%
match = re.search(pattern, text)

# %%
match.start()
# Out:
# 3

# %%
match.end()
# Out:
# 8

# %%
matches = re.findall('phone',text)

# %%
len(matches)
# Out:
# 2

# %%
for match in re.findall(pattern, text):
    print(match)
# Out:
# phone
# phone

# %%
for match in re.finditer(pattern, text):
    print(match)
# Out:
# <re.Match object; span=(3, 8), match='phone'>
# <re.Match object; span=(21, 26), match='phone'>

# %%
for match in re.finditer(pattern, text):
    print(match.span())
# Out:
# (3, 8)
# (21, 26)

# %%
for match in re.finditer(pattern, text):
    print(match.group())
# Out:
# phone
# phone

# %%
text = 'My phone number is 408-555-1234'

# %%
phone = re.search('\d{3}-\d{3}-\d{4}',text)

# %%
phone
# Out:
# <re.Match object; span=(19, 31), match='408-555-1234'>

# %%
print(phone)
# Out:
# <re.Match object; span=(19, 31), match='408-555-1234'>

# %%
phone_pattern = re.compile(r'(\d{3})-(\d{3})-(\d{4})')

# %%
results = re.search(phone_pattern,text)

# %%
results.group()
# Out:
# '408-555-1234'

# %%
results.group(1)
# Out:
# '408'

# %%
from datetime import date


def age_calculator(years, months, days):
    age_day = 0
    age_months = 0
    age_year = 0
    
    today_day = int(today.strftime("%d"))
    today_month = int(today.strftime("%m"))
    today_year = int(today.strftime('%Y'))
    
    print(today_day)
    print(today_month)
    print(today_year)
    
    if today_day < days:
        today_day += 31
        age_day = today_day - days
    else:
        age_day = today_day - days
        
        
    if today_month < months:
        today_month += 12
        age_months =  today_month - months
    else:
        age_months = today_month - months
        
    age_year = today_year - years
    
    print(f"Your age of today is : {today_year} - {today_month} - {today_day}")
    
    
today = date.today()

print("today's date is :", today)

birthDate = input("Enter your birth date in YYYY-MM-DD format:")
year, month, day = map(int, birthDate.split("-"))

print(year)
print(month)
print(day)
if month > 12  or day > 31 or year < int(today.strftime("%y")):
    print("Invalid date")
    exit()

print("Your date of birth is:", birthDate)


age_calculator(year, month,day)
# Out:
# today's date is : 2021-10-04

# %%
import requests as rq

from bs4 import BeautifulSoup



url = input("Enter a link")

if ("https" or "http") in url:
    data = rq.get(url)
else:
    data = rq.get("https://"+url)
    
    
soup = BeautifulSoup(data.txt,'htmal.parser')
    
links = []
for link in soup.find_all("a"):
    links.append(link.get("href"))
        
        
with open("mylinks.txt","a") as saved:
    print(links[:10],file=saved)
